# %%
#首先导入所需的库
import xml.etree.cElementTree as ET
from collections import Counter
from collections import defaultdict
import re
import csv
import codecs
import pprint
#import schema     
#import cerberus

# %%
#定义一个函数audit，返回一个字典，键是所有的街道类型，值是各街道类型对应的街道名集合
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)

def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m :
        street_type = m.group()
        street_types[street_type].add(street_name)

def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")

def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if (elem.tag=='tag') and is_street_name(elem):
            audit_street_type(street_types, elem.attrib['v'])
    osm_file.close()            
    return street_types

# %%
#将结果以一一对应的形式打出来观察
for m,n in audit('export.osm').items():
    for i in n:
        print m,i
# Out:
# Boulevard 北环大道 Beihuan Boulevard
# Boulevard 深南大道 Shennan Boulevard
# Boulevard Shennan Boulevard
# Boulevard 滨河大道 Binhe Boulevard
# Boulevard 南山大道 Nanshan Boulevard
# District Xili Town, Nanshan District
# 1號 金鸡路1號
# Rd 正云路 Zhengyun Rd
# Rd Futianxinsha Rd
# Rd 玉园路 Yuyuan Rd
# Rd Guihua Rd
# Rd 正风路 Zhengfeng Rd
# Rd 罗芳路 Luofang Rd
# Rd 延芳路 Yanfang Rd
# Rd 景田北街 Jingtian N Rd
# Rd 经二路 Jinger Rd
# Rd Gongye 7th Rd
# Rd 湖贝路 Hubei Rd
# Rd 莲花路 Lianhua Rd
# Rd 香梅路 Xiangmei Rd
# Rd 布龙路 Bulong Rd
# Rd 中山园路 Zhongshanyuan Rd
# Rd Zhenghua Rd
# Rd 中兴路 Zhongxing Rd
# Rd 景田西路 Jingtian W Rd
# Rd 景田路 Jingtian Rd
# Rd 粤兴三道 Yuexing 3rd Rd
# Rd 东门中路 Dongmen Middle Rd
# Rd 文锦中路 Wenjin Middle Rd
# Rd 新秀路 Xinxiu Rd
# Rd 欣园路 Xinyuan Rd
# Tin 青山公路 - 新田段 Castle Peak Road - San Tin
# Lu 沙河西路 ShaHe Xi Lu
# Lu KeYuan Lu
# Lu Hua Fa Bei Lu
# Lu 桃园路 Taoyuan Lu
# Lu Hongbao Lu
# S. Gaoxin S.
# BLVD Shennan BLVD
# Xinsha Xinsha
# CoCoPark 星河CoCoPark
# Highway 广深公路 Guangzhou-Shenzhen Highway
# B座2樓 海岸城中洲控股金融中心B座2樓
# 518000 1002 Huaqiang N Rd, HuaQiang Bei, Futian Qu, Shenzhen Shi, Guangdong Sheng, China, 518000
# 7道 高新科技園高新南7道
# Path 金錢徑 Kam Tsin Path
# A区 福中路市民中心A区
# Tung 青山公路 - 古洞段 Castle Peak Road - Kwu Tung
# 95約1049地段 香港新界上水河上鄉95約1049地段
# St 景田北五街 Jingtian North 5th St
# St 景田北七街 Jingtian North 7th St
# St 景田北三街 Jingtian North 3rd St
# St 景田东一街 Jingtian E 1st St
# St 景田北六街 Jingtian North 6th St
# St 景田北一街 Jingtian North 1st St
# St 景田北二街 Jingtian North 2nd St
# OCT-LOFT North Side of Building C2, North Dist. of OCT-LOFT
# Close 嘉富坊 Ka Fu Close
# 2層203-205號 海岸城購物中心2層203-205號
# 95約快景路 香港新界上水河上鄉95約快景路
# Road 金翠路 Kam Chui Road
# Road 市花路 Shihua Road
# Road 新運路 San Wan Road
# Road 彩園路 Choi Yuen Road
# Road 金科路 Jinke Road
# Road 福强路 Fuqiang Road
# Road Jockey Club Road
# Road 古洞路 Kwu Tung Road
# Road 福荣路 Furong Road
# Road Ching Hiu Road
# Road 寶運路 Po Wan Road
# Road 桂华路 Guihua Road
# Road 靈山路 Ling Shan Road
# Road Yi Yuan Road
# Road Hang Tau Road
# Road Po Kin Road
# Road Fung Nam Road
# Road Yitian 5th Road
# Road 益田路 Yitian Road
# Road Choi Yuen Road
# Road 和睦路 Wo Muk Road
# Road XinSha Road
# Road 深南东路 Shen Nan East Road
# Road 金錢南路 Kam Tsin South Road
# Road 石夏路 Shixia Road
# Road 馬適路 Ma Sik Road
# Road Man Kam To Road
# Road 金錢路 Kam Tsin Road
# Road 維翰路 Wai Hon Road
# Road Ma Sik Road
# Road Pik Fung Road
# Road 馬會道 Jockey Club Road
# Road 沙頭角公路 Sha Tau Kok Road
# Road 波樓路 Po Lau Road
# Road Xinsha Road
# Road 科苑路 Keyuan Road
# Road 新洲路 Xinzhou Road
# Road Tin Ping Road
# Road Chunfeng Road
# Road Sha He Road
# Road Po Wan Road
# Road Shennan Road
# Road 粉嶺樓路 Fan Leng Lau Road
# Road Dawei Road
# Road Chi Cheong Road
# Road Pak Wo Road
# Road Lok Ma Chau Road
# Road Po Ping Road
# Road 河上鄉路 Ho Sheung Heung Road
# Road 聯和道 Luen Wo Road
# Road  Xinsha Road
# Road 樂業路 Lok Yip Road
# Road Po Wing Road
# Road Xinzhou Road
# Tau 青山公路 - 洲頭段 Castle Peak Road - Chau Tau
# DaDao NanHai DaDao
# Street Wenchang South Street
# Street 彩發街 Choi Fat Street
# Street Shixia North 2nd Street
# Street 居適街 Kui Sik Street
# Street 安樂門街 On Lok Mun Street
# Street 聯發街 Luen Fat Street
# Street 安全街 On Chuen Street
# Street 新財街 San Tsoi Street
# Street 新發街 San Fat Street
# Street Lung Wan Street
# Street Luen Chit Street
# Street 樂天街 Lok Tin Street
# Street 安福街 On Fuk Street
# Street 和泰街 Wo Tai Street
# Street 新寶街 San Po Street
# Street 彩暉街 Choi Fai Street
# Street 和豐街 Wo Fung Street
# Street 新康街 San Hong Street
# Street Luen Yick Street
# Street 樂東街 Lok Tung Street
# Street Wo Mun Street
# Street San Hong Street
# Street 和滿街 Wo Mun Street
# Street Tsun Fu Street
# Street Shixia North 4th Street
# Street San Lok Street
# Street Shixia North 1st Street
# Street Fu Hing Street
# Street 業暢街 Yip Cheong Street
# Street 安居街 On Kui Street
# Street 金嘉街 Kam Ka Street
# Street 符興街 Fu Hing Street
# Street 樂鳴街 Lok Ming Street
# Street 聯興街 Luen Hing Street
# Street San Fat Street
# Crescent 吉祥街 Kat Cheung Crescent
# Av 坂雪岗大道 Bǎnxuě Gǎng Av
# Ave 北环大道 North Ring Ave
# Avenue San Fung Avenue
# Avenue Nanhai Avenue
# Avenue Lung Sum Avenue
# Avenue 龙岗大道 Longgang Avenue
# Avenue 龍琛路 Lung Sum Avenue
# Avenue 新豐路 San Fung Avenue
# Avenue Shennan Avenue
# Avenue San Shing Avenue
# road 福华路 Fuhua road
# road 民田路 Mintian road

# %%
#expected列表包含了我们所期望的规范化模板。
expected = ["Street", "Avenue", "Boulevard", "Road", 'District', 'Highway', 'Path']

#根据上面的结果，建立mapping字典，键是变更前的街道类型，值是变更后的街道类型，这里只修改英文字符，且对非街道类型不做修改。
mapping = { 'S':"Street",
            'S.':"Street",
            "St": "Street",   
            'Lu':'Road',
            'Rd':"Road",
            'road':'Road',
            'BLVD':"Boulevard",
            'DaDao':'Road',
            'Av':"Avenue",
            'Ave':"Avenue"
            }

def add_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)

#替换街道名中的街道类型
def update_name(name, mapping):
    shortname = mapping.keys()
    for word in shortname:
        if name.endswith(word):
            name = name.replace(word,mapping[word])
    return name

# %%
#呈现变更的成果
st_types = audit('export.osm')
for st_type, ways in st_types.iteritems():
    for name in ways:
        better_name = update_name(name, mapping)
        print name, "=>", better_name
# Out:
# 北环大道 Beihuan Boulevard => 北环大道 Beihuan Boulevard
# 深南大道 Shennan Boulevard => 深南大道 Shennan Boulevard
# Shennan Boulevard => Shennan Boulevard
# 滨河大道 Binhe Boulevard => 滨河大道 Binhe Boulevard
# 南山大道 Nanshan Boulevard => 南山大道 Nanshan Boulevard
# Xili Town, Nanshan District => Xili Town, Nanshan District
# 金鸡路1號 => 金鸡路1號
# 正云路 Zhengyun Rd => 正云路 Zhengyun Road
# Futianxinsha Rd => Futianxinsha Road
# 玉园路 Yuyuan Rd => 玉园路 Yuyuan Road
# Guihua Rd => Guihua Road
# 正风路 Zhengfeng Rd => 正风路 Zhengfeng Road
# 罗芳路 Luofang Rd => 罗芳路 Luofang Road
# 延芳路 Yanfang Rd => 延芳路 Yanfang Road
# 景田北街 Jingtian N Rd => 景田北街 Jingtian N Road
# 经二路 Jinger Rd => 经二路 Jinger Road
# Gongye 7th Rd => Gongye 7th Road
# 湖贝路 Hubei Rd => 湖贝路 Hubei Road
# 莲花路 Lianhua Rd => 莲花路 Lianhua Road
# 香梅路 Xiangmei Rd => 香梅路 Xiangmei Road
# 布龙路 Bulong Rd => 布龙路 Bulong Road
# 中山园路 Zhongshanyuan Rd => 中山园路 Zhongshanyuan Road
# Zhenghua Rd => Zhenghua Road
# 中兴路 Zhongxing Rd => 中兴路 Zhongxing Road
# 景田西路 Jingtian W Rd => 景田西路 Jingtian W Road
# 景田路 Jingtian Rd => 景田路 Jingtian Road
# 粤兴三道 Yuexing 3rd Rd => 粤兴三道 Yuexing 3rd Road
# 东门中路 Dongmen Middle Rd => 东门中路 Dongmen Middle Road
# 文锦中路 Wenjin Middle Rd => 文锦中路 Wenjin Middle Road
# 新秀路 Xinxiu Rd => 新秀路 Xinxiu Road
# 欣园路 Xinyuan Rd => 欣园路 Xinyuan Road
# 青山公路 - 新田段 Castle Peak Road - San Tin => 青山公路 - 新田段 Castle Peak Road - San Tin
# 沙河西路 ShaHe Xi Lu => 沙河西路 ShaHe Xi Road
# KeYuan Lu => KeYuan Road
# Hua Fa Bei Lu => Hua Fa Bei Road
# 桃园路 Taoyuan Lu => 桃园路 Taoyuan Road
# Hongbao Lu => Hongbao Road
# Gaoxin S. => Gaoxin Street
# Shennan BLVD => Shennan Boulevard
# Xinsha => Xinsha
# 星河CoCoPark => 星河CoCoPark
# 广深公路 Guangzhou-Shenzhen Highway => 广深公路 Guangzhou-Shenzhen Highway
# 海岸城中洲控股金融中心B座2樓 => 海岸城中洲控股金融中心B座2樓
# 1002 Huaqiang N Rd, HuaQiang Bei, Futian Qu, Shenzhen Shi, Guangdong Sheng, China, 518000 => 1002 Huaqiang N Rd, HuaQiang Bei, Futian Qu, Shenzhen Shi, Guangdong Sheng, China, 518000
# 高新科技園高新南7道 => 高新科技園高新南7道
# 金錢徑 Kam Tsin Path => 金錢徑 Kam Tsin Path
# 福中路市民中心A区 => 福中路市民中心A区
# 青山公路 - 古洞段 Castle Peak Road - Kwu Tung => 青山公路 - 古洞段 Castle Peak Road - Kwu Tung
# 香港新界上水河上鄉95約1049地段 => 香港新界上水河上鄉95約1049地段
# 景田北五街 Jingtian North 5th St => 景田北五街 Jingtian North 5th Street
# 景田北七街 Jingtian North 7th St => 景田北七街 Jingtian North 7th Street
# 景田北三街 Jingtian North 3rd St => 景田北三街 Jingtian North 3rd Street
# 景田东一街 Jingtian E 1st St => 景田东一街 Jingtian E 1st Street
# 景田北六街 Jingtian North 6th St => 景田北六街 Jingtian North 6th Street
# 景田北一街 Jingtian North 1st St => 景田北一街 Jingtian North 1st Street
# 景田北二街 Jingtian North 2nd St => 景田北二街 Jingtian North 2nd Street
# North Side of Building C2, North Dist. of OCT-LOFT => North Side of Building C2, North Dist. of OCT-LOFT
# 嘉富坊 Ka Fu Close => 嘉富坊 Ka Fu Close
# 海岸城購物中心2層203-205號 => 海岸城購物中心2層203-205號
# 香港新界上水河上鄉95約快景路 => 香港新界上水河上鄉95約快景路
# 金翠路 Kam Chui Road => 金翠路 Kam Chui Road
# 市花路 Shihua Road => 市花路 Shihua Road
# 新運路 San Wan Road => 新運路 San Wan Road
# 彩園路 Choi Yuen Road => 彩園路 Choi Yuen Road
# 金科路 Jinke Road => 金科路 Jinke Road
# 福强路 Fuqiang Road => 福强路 Fuqiang Road
# Jockey Club Road => Jockey Club Road
# 古洞路 Kwu Tung Road => 古洞路 Kwu Tung Road
# 福荣路 Furong Road => 福荣路 Furong Road
# Ching Hiu Road => Ching Hiu Road
# 寶運路 Po Wan Road => 寶運路 Po Wan Road
# 桂华路 Guihua Road => 桂华路 Guihua Road
# 靈山路 Ling Shan Road => 靈山路 Ling Shan Road
# Yi Yuan Road => Yi Yuan Road
# Hang Tau Road => Hang Tau Road
# Po Kin Road => Po Kin Road
# Fung Nam Road => Fung Nam Road
# Yitian 5th Road => Yitian 5th Road
# 益田路 Yitian Road => 益田路 Yitian Road
# Choi Yuen Road => Choi Yuen Road
# 和睦路 Wo Muk Road => 和睦路 Wo Muk Road
# XinSha Road => XinSha Road
# 深南东路 Shen Nan East Road => 深南东路 Shen Nan East Road
# 金錢南路 Kam Tsin South Road => 金錢南路 Kam Tsin South Road
# 石夏路 Shixia Road => 石夏路 Shixia Road
# 馬適路 Ma Sik Road => 馬適路 Ma Sik Road
# Man Kam To Road => Man Kam To Road
# 金錢路 Kam Tsin Road => 金錢路 Kam Tsin Road
# 維翰路 Wai Hon Road => 維翰路 Wai Hon Road
# Ma Sik Road => Ma Sik Road
# Pik Fung Road => Pik Fung Road
# 馬會道 Jockey Club Road => 馬會道 Jockey Club Road
# 沙頭角公路 Sha Tau Kok Road => 沙頭角公路 Sha Tau Kok Road
# 波樓路 Po Lau Road => 波樓路 Po Lau Road
# Xinsha Road => Xinsha Road
# 科苑路 Keyuan Road => 科苑路 Keyuan Road
# 新洲路 Xinzhou Road => 新洲路 Xinzhou Road
# Tin Ping Road => Tin Ping Road
# Chunfeng Road => Chunfeng Road
# Sha He Road => Sha He Road
# Po Wan Road => Po Wan Road
# Shennan Road => Shennan Road
# 粉嶺樓路 Fan Leng Lau Road => 粉嶺樓路 Fan Leng Lau Road
# Dawei Road => Dawei Road
# Chi Cheong Road => Chi Cheong Road
# Pak Wo Road => Pak Wo Road
# Lok Ma Chau Road => Lok Ma Chau Road
# Po Ping Road => Po Ping Road
# 河上鄉路 Ho Sheung Heung Road => 河上鄉路 Ho Sheung Heung Road
# 聯和道 Luen Wo Road => 聯和道 Luen Wo Road
#  Xinsha Road =>  Xinsha Road
# 樂業路 Lok Yip Road => 樂業路 Lok Yip Road
# Po Wing Road => Po Wing Road
# Xinzhou Road => Xinzhou Road
# 青山公路 - 洲頭段 Castle Peak Road - Chau Tau => 青山公路 - 洲頭段 Castle Peak Road - Chau Tau
# NanHai DaDao => NanHai Road
# Wenchang South Street => Wenchang South Street
# 彩發街 Choi Fat Street => 彩發街 Choi Fat Street
# Shixia North 2nd Street => Shixia North 2nd Street
# 居適街 Kui Sik Street => 居適街 Kui Sik Street
# 安樂門街 On Lok Mun Street => 安樂門街 On Lok Mun Street
# 聯發街 Luen Fat Street => 聯發街 Luen Fat Street
# 安全街 On Chuen Street => 安全街 On Chuen Street
# 新財街 San Tsoi Street => 新財街 San Tsoi Street
# 新發街 San Fat Street => 新發街 San Fat Street
# Lung Wan Street => Lung Wan Street
# Luen Chit Street => Luen Chit Street
# 樂天街 Lok Tin Street => 樂天街 Lok Tin Street
# 安福街 On Fuk Street => 安福街 On Fuk Street
# 和泰街 Wo Tai Street => 和泰街 Wo Tai Street
# 新寶街 San Po Street => 新寶街 San Po Street
# 彩暉街 Choi Fai Street => 彩暉街 Choi Fai Street
# 和豐街 Wo Fung Street => 和豐街 Wo Fung Street
# 新康街 San Hong Street => 新康街 San Hong Street
# Luen Yick Street => Luen Yick Street
# 樂東街 Lok Tung Street => 樂東街 Lok Tung Street
# Wo Mun Street => Wo Mun Street
# San Hong Street => San Hong Street
# 和滿街 Wo Mun Street => 和滿街 Wo Mun Street
# Tsun Fu Street => Tsun Fu Street
# Shixia North 4th Street => Shixia North 4th Street
# San Lok Street => San Lok Street
# Shixia North 1st Street => Shixia North 1st Street
# Fu Hing Street => Fu Hing Street
# 業暢街 Yip Cheong Street => 業暢街 Yip Cheong Street
# 安居街 On Kui Street => 安居街 On Kui Street
# 金嘉街 Kam Ka Street => 金嘉街 Kam Ka Street
# 符興街 Fu Hing Street => 符興街 Fu Hing Street
# 樂鳴街 Lok Ming Street => 樂鳴街 Lok Ming Street
# 聯興街 Luen Hing Street => 聯興街 Luen Hing Street
# San Fat Street => San Fat Street
# 吉祥街 Kat Cheung Crescent => 吉祥街 Kat Cheung Crescent
# 坂雪岗大道 Bǎnxuě Gǎng Av => 坂雪岗大道 Bǎnxuě Gǎng Avenue
# 北环大道 North Ring Ave => 北环大道 North Ring Avenue
# San Fung Avenue => San Fung Avenue
# Nanhai Avenue => Nanhai Avenue
# Lung Sum Avenue => Lung Sum Avenue
# 龙岗大道 Longgang Avenue => 龙岗大道 Longgang Avenue
# 龍琛路 Lung Sum Avenue => 龍琛路 Lung Sum Avenue
# 新豐路 San Fung Avenue => 新豐路 San Fung Avenue
# Shennan Avenue => Shennan Avenue
# San Shing Avenue => San Shing Avenue
# 福华路 Fuhua road => 福华路 Fuhua Road
# 民田路 Mintian road => 民田路 Mintian Road

# %%
#定义函数shape_element，将XML的元素从文档形式转换为能够写入CSV的数据结构

LOWER_COLON = re.compile(r'^([a-z]|_)+:([a-z]|_)+')
PROBLEMCHARS = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

NODE_FIELDS = ['id', 'lat', 'lon', 'user', 'uid', 'version', 'changeset', 'timestamp']
NODE_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_FIELDS = ['id', 'user', 'uid', 'version', 'changeset', 'timestamp']
WAY_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_NODES_FIELDS = ['id', 'node_id', 'position']

def shape_element(element, node_attr_fields=NODE_FIELDS, way_attr_fields=WAY_FIELDS,
                  problem_chars=PROBLEMCHARS, default_tag_type='regular'):
    """Clean and shape node or way XML element to Python dict"""

    node_attribs = {}
    way_attribs = {}
    way_nodes = []
    tags=[]
    m=0  #要在for child in element:循环之前规定，否则每次一循环就归零了
    # YOUR CODE HERE
    if element.tag == 'node':
        for i in NODE_FIELDS:
            node_attribs[i]=element.get(i)
        if element.find('tag') is not None:
            for tag in element.iter('tag'):  #iter生成迭代来查询
                tag_dict={}   #定义要在for循环里面，因为如果是字典嵌套在列表里，每个字典又有共同的key,定义在外面会导致字典的值都是最后一次循环的，详细参考word
                if PROBLEMCHARS.search(tag.get('k')): #如果k值存在问题
                    continue   #即当满足该条件时跳过，继续循环，这里也可以用‘pass’
                else:  #如果k值不存在问题
                    tag_dict['id']=element.get('id')
                    tag_dict['value']=tag.get('v')
                    if LOWER_COLON.search(tag.attrib['k']): #如果k值存在冒号
                        tag_dict['key']=tag.get('k').split(':',1)[1] #以冒号来分隔一次，取第二个元素，PS：split是返回分隔后字符串的列表
                        tag_dict['type']=tag.get('k').split(':',1)[0]
                    else: #如果k值不存在冒号
                        tag_dict['key']=tag.get('k')
                        tag_dict['type']='regular'
                tags.append(tag_dict)
        else:
            pass  #如果不存在次级标记，就啥也不做，即tags还是空列表
        return {'node': node_attribs, 'node_tags': tags}
    elif element.tag == 'way':
        for p in WAY_FIELDS:
            way_attribs[p]=element.get(p)
        for child in element:
            if child.tag=='tag':
                tag_dict={}
                if PROBLEMCHARS.search(child.get('k')):
                    continue
                else:
                    tag_dict['id']=element.get('id')
                    tag_dict['value']=child.get('v')
                    if LOWER_COLON.search(child.attrib['k']):
                        tag_dict['key']=child.get('k').split(':',1)[1]
                        tag_dict['type']=child.get('k').split(':',1)[0]
                    else:
                        tag_dict['key']=child.get('k')
                        tag_dict['type']='regular'
                tags.append(tag_dict)
            elif child.tag is None:
                pass
            elif child.tag=='nd':
                way_dict={}
                way_dict['id']=element.get('id')
                way_dict['node_id']=child.get('ref')
                way_dict['position']=m
                m+=1
                way_nodes.append(way_dict)
        return {'way': way_attribs, 'way_nodes': way_nodes, 'way_tags': tags}

# %%
#将每个数据结构写入相应的 .csv 文件

#SCHEMA = schema.schema

NODES_PATH = "nodes.csv"
NODE_TAGS_PATH = "nodes_tags.csv"
WAYS_PATH = "ways.csv"
WAY_NODES_PATH = "ways_nodes.csv"
WAY_TAGS_PATH = "ways_tags.csv"


def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag"""

    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()
            
#因为课程中的习题已经做过验证了，这里不再重复
#def validate_element(element, validator, schema=SCHEMA):
#    """Raise ValidationError if element does not match schema"""
#    if validator.validate(element, schema) is not True:
#         field, errors = next(validator.errors.iteritems())
#         message_string = "\nElement of type '{0}' has the following errors:\n{1}"
#         error_string = pprint.pformat(errors)
        
#        raise Exception(message_string.format(field, error_string))
        
class UnicodeDictWriter(csv.DictWriter, object):
    """Extend csv.DictWriter to handle Unicode input"""

    def writerow(self, row):
        super(UnicodeDictWriter, self).writerow({
            k: (v.encode('utf-8') if isinstance(v, unicode) else v) for k, v in row.iteritems()
        })

    def writerows(self, rows):
        for row in rows:
            self.writerow(row)
            
def process_map(file_in, validate):
    """Iteratively process each XML element and write to csv(s)"""

    with codecs.open(NODES_PATH, 'w') as nodes_file, \
         codecs.open(NODE_TAGS_PATH, 'w') as nodes_tags_file, \
         codecs.open(WAYS_PATH, 'w') as ways_file, \
         codecs.open(WAY_NODES_PATH, 'w') as way_nodes_file, \
         codecs.open(WAY_TAGS_PATH, 'w') as way_tags_file:

        nodes_writer = UnicodeDictWriter(nodes_file, NODE_FIELDS)
        node_tags_writer = UnicodeDictWriter(nodes_tags_file, NODE_TAGS_FIELDS)
        ways_writer = UnicodeDictWriter(ways_file, WAY_FIELDS)
        way_nodes_writer = UnicodeDictWriter(way_nodes_file, WAY_NODES_FIELDS)
        way_tags_writer = UnicodeDictWriter(way_tags_file, WAY_TAGS_FIELDS)

        nodes_writer.writeheader()
        node_tags_writer.writeheader()
        ways_writer.writeheader()
        way_nodes_writer.writeheader()
        way_tags_writer.writeheader()
        
       #validator = cerberus.Validator()


        for element in get_element(file_in, tags=('node', 'way')):
            el = shape_element(element)
            if el:
               #if validate is True:
                    #validate_element(el, validator)
                if element.tag == 'node':
                    nodes_writer.writerow(el['node'])
                    node_tags_writer.writerows(el['node_tags'])
                elif element.tag == 'way':
                    ways_writer.writerow(el['way'])
                    way_nodes_writer.writerows(el['way_nodes'])
                    way_tags_writer.writerows(el['way_tags'])
                    
if __name__ == '__main__':
    process_map('export.osm',validate =False)
